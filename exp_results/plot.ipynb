# %%
import matplotlib.pyplot as plt
import glob
from plot import populate_data, draw, STAT

# %%
d_fifo_res = populate_data("d-fifo.out")

# %%
        # "block_time_us": [],
        # "runnable_time_us": [],
        # "queued_time_us": [],
        # "on_cpu_time_us": [],
        # "yielding_time_us": [],

draw(d_fifo_res, STAT.MEAN, "block_time_us")
draw(d_fifo_res, STAT.MEAN, "runnable_time_us")
draw(d_fifo_res, STAT.MEAN, "queued_time_us")
draw(d_fifo_res, STAT.MEAN, "on_cpu_time_us")
draw(d_fifo_res, STAT.MEAN, "yielding_time_us")
# Out:
# 1
# 1
# 1
# 1
# 1

# %%
c_fifo_res = populate_data("c-fifo.out")

# %%
draw(c_fifo_res, STAT.STDEV, "block_time_us")
draw(c_fifo_res, STAT.STDEV, "runnable_time_us")
draw(c_fifo_res, STAT.STDEV, "queued_time_us")
draw(c_fifo_res, STAT.STDEV, "on_cpu_time_us")
# Out:
# 2
# 2
# 2
# 2
